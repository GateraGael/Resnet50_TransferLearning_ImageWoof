# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os
import sys

# %%
tf.debugging.set_log_device_placement(False)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Found GPU at: /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# # Importing My Own Functions

# %%
import run_fast_dir

# %%
tf.__version__
# Out:
# '2.8.0-dev20211216'

# %% [markdown]
# # Size of Data in training and validation Sets

# %%
sub_folders, and_files = run_fast_dir.run_fast_scandir('./Data/imagewoof-320/train',['.jpeg'])
print(f'The Training Dataset contains {len(and_files)} images')
# Out:
# The Training Dataset contains 12454 images

# %%
BATCH_SIZE = 32
IMG_SIZE = (160, 160)

train_dir = './Data/imagewoof-320/train'

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                          shuffle=True,
                                                          batch_size=BATCH_SIZE,
                                                          image_size=IMG_SIZE)
# Out:
# Found 12454 files belonging to 10 classes.

# %%
sub_folders, and_files = run_fast_dir.run_fast_scandir('./Data/imagewoof-320/val',['.jpeg'])
print(f'The Validation Dataset contains {len(and_files)} images')
# Out:
# The Validation Dataset contains 500 images

# %%
validation_dir = './Data/imagewoof-320/val'

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(validation_dir,
                                                              shuffle=True,
                                                              batch_size=BATCH_SIZE,
                                                              image_size=IMG_SIZE)
# Out:
# Found 500 files belonging to 10 classes.

# %% [markdown]
# # Moving 20% of validation data to a test set
# We do not have a test set therefore will set aside some of the validation data to a test set, this will still overfit our model since our validation data is only 500 images however it is important to see how much of an improvement we can make (will evaluate further down the line).

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
validation_dataset = validation_dataset.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 13
# Number of test batches: 3

# %% [markdown]
# # Buffered Prefetching
# Per [Data Performance Guide](https://www.tensorflow.org/guide/data_performance)I/O can become a problem for the execution time of a training step. Therefore we will need something that enables the configuration of the dataset for peak erformance.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.resnet50.preprocess_input

# %%
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset=-1)

# %% [markdown]
# # Feature Extraction
# ## Freeze the convolutional base

# %%
IMG_SHAPE = IMG_SIZE + (3,)
res_net2 = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                            include_top=False,
                                            weights='imagenet')

for layer in res_net2.layers:
  layer.trainable = False

# %%
x = tf.keras.layers.Flatten()(res_net2.output)
x = tf.keras.layers.Dense(1000, activation='relu')(x)
predictions = tf.keras.layers.Dense(10, activation = 'softmax')(x)

# %%
base_learning_rate = 0.0001
head_model = tf.keras.Model(inputs = res_net2.input, outputs = predictions)
head_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate), 
                   loss=tf.keras.losses.sparse_categorical_crossentropy, 
                   metrics=['accuracy'])

# %%
len(head_model.trainable_variables)
# Out:
# 4

# %%
initial_epochs = 10
loss0, accuracy0 = head_model.evaluate(validation_dataset)
# Out:
# 13/13 [==============================] - 6s 108ms/step - loss: 5.6788 - accuracy: 0.1040

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# initial loss: 5.68
# initial accuracy: 0.10

# %%
history = head_model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/10
# 390/390 [==============================] - 27s 62ms/step - loss: 1.0852 - accuracy: 0.7422 - val_loss: 0.7442 - val_accuracy: 0.7649
# Epoch 2/10
# 390/390 [==============================] - 24s 62ms/step - loss: 0.2000 - accuracy: 0.9357 - val_loss: 0.7226 - val_accuracy: 0.7574
# Epoch 3/10
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0684 - accuracy: 0.9783 - val_loss: 0.8479 - val_accuracy: 0.7698
# Epoch 4/10
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0422 - accuracy: 0.9884 - val_loss: 0.9964 - val_accuracy: 0.7525
# Epoch 5/10
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0402 - accuracy: 0.9894 - val_loss: 1.0394 - val_accuracy: 0.7673
# Epoch 6/10
# 390/390 [==============================] - 25s 63ms/step - loss: 0.1001 - accuracy: 0.9676 - val_loss: 1.4810 - val_accuracy: 0.7475
# Epoch 7/10
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0888 - accuracy: 0.9710 - val_loss: 1.3074 - val_accuracy: 0.7574
# Epoch 8/10
# 390/390 [==============================] - 25s 64ms/step - loss: 0.0526 - accuracy: 0.9826 - val_loss: 1.5185 - val_accuracy: 0.7327
# Epoch 9/10
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0474 - accuracy: 0.9873 - val_loss: 1.5990 - val_accuracy: 0.7500
# Epoch 10/10
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0464 - accuracy: 0.9876 - val_loss: 1.7054 - val_accuracy: 0.7698

# %%
Trial_num = 3
output_path = './Results/'
folder_name = f'Trial{str(Trial_num)}'

if not os.path.exists(output_path + folder_name):
    os.makedirs(output_path + folder_name)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

#plt.figure(figsize=(8, 8))
#plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title(f'Trial {Trial_num} T&V Accuracy {base_learning_rate}')
plt.savefig(output_path + '/' + folder_name + '/' + f'Trial {Trial_num} T&V Accuracy {base_learning_rate}.jpeg')
plt.xlabel('epoch')
plt.show()
#plt.close()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

#plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title(f'Trial {Trial_num} T&V Loss {base_learning_rate}')
plt.savefig(output_path + '/' + folder_name + '/' + f'Trial {Trial_num} T&V Loss {base_learning_rate}.jpeg')
plt.xlabel('epoch')
plt.show()
#plt.close()

# %% [markdown]
# # Unfreeze Base Model

# %%
for layer in res_net2.layers:
  layer.trainable = True

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(head_model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in head_model.layers[:fine_tune_at]:
  layer.trainable =  False
# Out:
# Number of layers in the base model:  178

# %%
# Reducing My Learning Rate
head_model = tf.keras.Model(inputs = res_net2.input, outputs = predictions)
head_model.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10), 
                   loss=tf.keras.losses.sparse_categorical_crossentropy, 
                   metrics=['accuracy'])

# %%
len(head_model.trainable_variables)
# Out:
# 4

# %%
fine_tune_epochs = 10
total_epochs =  initial_epochs + fine_tune_epochs

history_fine = head_model.fit(train_dataset,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=validation_dataset)
# Out:
# Epoch 10/20
# 390/390 [==============================] - 31s 72ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 1.6911 - val_accuracy: 0.7822
# Epoch 11/20
# 390/390 [==============================] - 28s 71ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 1.7844 - val_accuracy: 0.7822
# Epoch 12/20
# 390/390 [==============================] - 28s 71ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.9761 - val_accuracy: 0.7896
# Epoch 13/20
# 390/390 [==============================] - 28s 72ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 2.0560 - val_accuracy: 0.7797
# Epoch 14/20
# 390/390 [==============================] - 28s 72ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 1.9311 - val_accuracy: 0.7871
# Epoch 15/20
# 390/390 [==============================] - 28s 72ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 2.3343 - val_accuracy: 0.7599
# Epoch 16/20
# 390/390 [==============================] - 28s 73ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 2.2807 - val_accuracy: 0.7673
# Epoch 17/20
# 390/390 [==============================] - 28s 73ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 2.1634 - val_accuracy: 0.7748
# Epoch 18/20
# 390/390 [==============================] - 28s 73ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 2.2148 - val_accuracy: 0.7673
# Epoch 19/20
# 390/390 [==============================] - 28s 73ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 2.3054 - val_accuracy: 0.7649
# Epoch 20/20
# 390/390 [==============================] - 28s 73ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 2.1115 - val_accuracy: 0.7896

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title(f'Trial {Trial_num} T&V Accuracy {base_learning_rate}')
plt.savefig(output_path + '/' + folder_name + '/' + f'Trial {Trial_num} T&V Accuracy_FineTuned.jpeg')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.plot([initial_epochs-1,initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.savefig(output_path + '/' + folder_name + '/' + f'Trial {Trial_num} T&V Loss_FineTuned.jpeg')
plt.show()

# %% [markdown]
# # Evaluation and prediction

# %%
loss, accuracy = head_model.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# 3/3 [==============================] - 0s 54ms/step - loss: 2.3595 - accuracy: 0.7292
# Test accuracy : 0.7291666865348816
